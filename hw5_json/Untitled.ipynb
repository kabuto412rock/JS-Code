# %%
import numpy as np
import cv2

img = cv2.imread('back.png', 0)

height, width = (img.shape)
for i in range(0, width):
    print(img[height//2][i])
# Out:
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 191
# 192
# 191
# 192
# 191
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 192
# 200
# 207
# 232
# 222
# 157
# 90
# 68
# 123
# 74
# 17
# 15
# 28
# 22
# 11
# 31
# 47
# 4
# 2
# 31
# 4
# 22
# 6
# 0
# 5
# 4
# 22
# 79
# 29
# 14
# 15
# 19
# 35
# 47
# 37
# ...
